# %% [markdown]
# # LeNet5

# %% [markdown]
# ### Settings

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import os
from helper_evaluation import set_all_seeds, set_deterministic
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples

RANDOM_SEED = 1
BATCH_SIZE = 256
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Data Loading

# %%
# Set random seed
set_all_seeds(RANDOM_SEED)
set_deterministic()

transform = torchvision.transforms.Compose([
        torchvision.transforms.Resize((32,32)),
        torchvision.transforms.Grayscale(),
        torchvision.transforms.ToTensor(), 
        torchvision.transforms.Normalize((0.5,),(0.5,))
    ])

# Load images 
dataset_dir = './data'
dataset = torchvision.datasets.ImageFolder(root = dataset_dir, transform = transform)

# Determine sizes of the training set and the test set
total_size = len(dataset)
train_size = int(np.floor(total_size * 0.6))
test_size = int(np.floor(total_size * 0.3))
valid_size = total_size - test_size - train_size

# %%
# Split the entire dataset into 60% of training set, 30% of test set, and 10% validation set.
training_dataset, test_dataset, valid_dataset = torch.utils.data.random_split(dataset, [train_size, test_size, valid_size])

# %%
# Loaders
train_loader = torch.utils.data.DataLoader(training_dataset, batch_size = BATCH_SIZE, shuffle = False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle = False)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size = BATCH_SIZE, shuffle = False)

# %%
training_dataset

# %% [markdown]
# ### Model

# %%
class LeNet5(torch.nn.Module):
    def __init__(self, num_classes, grayscale = False):
        super().__init__()
        self.grayscale = grayscale
        self.num_classes = num_classes
        
        if self.grayscale:
            in_channels = 1
        else:
            in_channels = 3
        
        self.features = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels, 6, kernel_size = 5),
            torch.nn.BatchNorm2d(6),
            torch.nn.Tanh(),
            torch.nn.MaxPool2d(kernel_size =2),
            
            torch.nn.Conv2d(6,16,kernel_size = 5),
            torch.nn.BatchNorm2d(16),
            torch.nn.Tanh(),
            torch.nn.MaxPool2d(kernel_size = 2)    
        )
        self.classifier = torch.nn.Sequential(
            torch.nn.Linear(16*5*5, 120),
            torch.nn.BatchNorm1d(120),
            torch.nn.Tanh(),
            torch.nn.Linear(120,84),
            torch.nn.BatchNorm1d(84),
            torch.nn.Tanh(),
            torch.nn.Linear(84,num_classes)          
        )
        
    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x,1)
        logits = self.classifier(x)
        return logits

# %%
model = LeNet5(grayscale = True, num_classes = 2)
model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr = 0.1, momentum = 0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.1,
                                                       mode='max',
                                                       verbose=True)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    test_loader=test_loader,
    valid_loader = valid_loader,
    optimizer=optimizer,
    device=DEVICE,
    logging_interval=3)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=100)
plt.savefig('LeNet5_training_loss.png')
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([80, 100])
plt.savefig('LeNet5_accuracy.png')
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0018 | Loss: 0.6805
# Epoch: 001/050 | Batch 0003/0018 | Loss: 0.6666
# Epoch: 001/050 | Batch 0006/0018 | Loss: 0.5909
# Epoch: 001/050 | Batch 0009/0018 | Loss: 0.5683
# Epoch: 001/050 | Batch 0012/0018 | Loss: 0.5699
# d:\users\asus\appdata\local\programs\python\python39\lib\site-packages\PIL\Image.py:951: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch: 001/050 | Batch 0015/0018 | Loss: 0.5508
# Epoch: 001/050 | Train: 67.73% | Validation: 66.45%
# Time elapsed: 0.54 min
# Epoch: 002/050 | Batch 0000/0018 | Loss: 0.5779
# Epoch: 002/050 | Batch 0003/0018 | Loss: 0.5759
# Epoch: 002/050 | Batch 0006/0018 | Loss: 0.5527
# Epoch: 002/050 | Batch 0009/0018 | Loss: 0.4827
# Epoch: 002/050 | Batch 0012/0018 | Loss: 0.4775
# Epoch: 002/050 | Batch 0015/0018 | Loss: 0.4518
# Epoch: 002/050 | Train: 75.88% | Validation: 75.69%
# Time elapsed: 0.94 min
# Epoch: 003/050 | Batch 0000/0018 | Loss: 0.4090
# Epoch: 003/050 | Batch 0003/0018 | Loss: 0.4199
# Epoch: 003/050 | Batch 0006/0018 | Loss: 0.4232
# Epoch: 003/050 | Batch 0009/0018 | Loss: 0.4181
# Epoch: 003/050 | Batch 0012/0018 | Loss: 0.4763
# Epoch: 003/050 | Batch 0015/0018 | Loss: 0.3690
# Epoch: 003/050 | Train: 78.46% | Validation: 78.20%
# Time elapsed: 1.34 min
# Epoch: 004/050 | Batch 0000/0018 | Loss: 0.3821
# Epoch: 004/050 | Batch 0003/0018 | Loss: 0.3239
# Epoch: 004/050 | Batch 0006/0018 | Loss: 0.3559
# Epoch: 004/050 | Batch 0009/0018 | Loss: 0.3749
# Epoch: 004/050 | Batch 0012/0018 | Loss: 0.3027
# Epoch: 004/050 | Batch 0015/0018 | Loss: 0.2802
# Epoch: 004/050 | Train: 84.33% | Validation: 81.37%
# Time elapsed: 1.76 min
# Epoch: 005/050 | Batch 0000/0018 | Loss: 0.3357
# Epoch: 005/050 | Batch 0003/0018 | Loss: 0.2673
# Epoch: 005/050 | Batch 0006/0018 | Loss: 0.3130
# Epoch: 005/050 | Batch 0009/0018 | Loss: 0.3188
# Epoch: 005/050 | Batch 0012/0018 | Loss: 0.2830
# Epoch: 005/050 | Batch 0015/0018 | Loss: 0.2590
# Epoch: 005/050 | Train: 86.56% | Validation: 84.28%
# Time elapsed: 2.21 min
# Epoch: 006/050 | Batch 0000/0018 | Loss: 0.3004
# Epoch: 006/050 | Batch 0003/0018 | Loss: 0.2106
# Epoch: 006/050 | Batch 0006/0018 | Loss: 0.2838
# Epoch: 006/050 | Batch 0009/0018 | Loss: 0.2782
# Epoch: 006/050 | Batch 0012/0018 | Loss: 0.2436
# Epoch: 006/050 | Batch 0015/0018 | Loss: 0.2121
# Epoch: 006/050 | Train: 82.01% | Validation: 80.71%
# Time elapsed: 2.62 min
# Epoch: 007/050 | Batch 0000/0018 | Loss: 0.2650
# Epoch: 007/050 | Batch 0003/0018 | Loss: 0.2085
# Epoch: 007/050 | Batch 0006/0018 | Loss: 0.2430
# Epoch: 007/050 | Batch 0009/0018 | Loss: 0.2835
# Epoch: 007/050 | Batch 0012/0018 | Loss: 0.2512
# Epoch: 007/050 | Batch 0015/0018 | Loss: 0.2400
# Epoch: 007/050 | Train: 85.79% | Validation: 81.64%
# Time elapsed: 3.03 min
# Epoch: 008/050 | Batch 0000/0018 | Loss: 0.2243
# Epoch: 008/050 | Batch 0003/0018 | Loss: 0.2071
# Epoch: 008/050 | Batch 0006/0018 | Loss: 0.2856
# Epoch: 008/050 | Batch 0009/0018 | Loss: 0.2936
# Epoch: 008/050 | Batch 0012/0018 | Loss: 0.2518
# Epoch: 008/050 | Batch 0015/0018 | Loss: 0.2139
# Epoch: 008/050 | Train: 84.90% | Validation: 80.18%
# Time elapsed: 3.43 min
# Epoch: 009/050 | Batch 0000/0018 | Loss: 0.2307
# Epoch: 009/050 | Batch 0003/0018 | Loss: 0.2343
# Epoch: 009/050 | Batch 0006/0018 | Loss: 0.2414
# Epoch: 009/050 | Batch 0009/0018 | Loss: 0.2113
# Epoch: 009/050 | Batch 0012/0018 | Loss: 0.2004
# Epoch: 009/050 | Batch 0015/0018 | Loss: 0.1911
# Epoch: 009/050 | Train: 91.00% | Validation: 84.28%
# Time elapsed: 3.83 min
# Epoch: 010/050 | Batch 0000/0018 | Loss: 0.2015
# Epoch: 010/050 | Batch 0003/0018 | Loss: 0.2053
# Epoch: 010/050 | Batch 0006/0018 | Loss: 0.1841
# Epoch: 010/050 | Batch 0009/0018 | Loss: 0.1904
# Epoch: 010/050 | Batch 0012/0018 | Loss: 0.1817
# Epoch: 010/050 | Batch 0015/0018 | Loss: 0.1762
# Epoch: 010/050 | Train: 88.24% | Validation: 83.49%
# Time elapsed: 4.24 min
# Epoch: 011/050 | Batch 0000/0018 | Loss: 0.2178
# Epoch: 011/050 | Batch 0003/0018 | Loss: 0.2258
# Epoch: 011/050 | Batch 0006/0018 | Loss: 0.1868
# Epoch: 011/050 | Batch 0009/0018 | Loss: 0.2219
# Epoch: 011/050 | Batch 0012/0018 | Loss: 0.1865
# Epoch: 011/050 | Batch 0015/0018 | Loss: 0.1598
# Epoch: 011/050 | Train: 79.32% | Validation: 75.56%
# Time elapsed: 4.64 min
# Epoch: 012/050 | Batch 0000/0018 | Loss: 0.1869
# Epoch: 012/050 | Batch 0003/0018 | Loss: 0.1358
# Epoch: 012/050 | Batch 0006/0018 | Loss: 0.1682
# Epoch: 012/050 | Batch 0009/0018 | Loss: 0.1677
# Epoch: 012/050 | Batch 0012/0018 | Loss: 0.1941
# Epoch: 012/050 | Batch 0015/0018 | Loss: 0.1232
# Epoch: 012/050 | Train: 87.64% | Validation: 82.83%
# Time elapsed: 5.05 min
# Epoch: 013/050 | Batch 0000/0018 | Loss: 0.1463
# Epoch: 013/050 | Batch 0003/0018 | Loss: 0.1682
# Epoch: 013/050 | Batch 0006/0018 | Loss: 0.1985
# Epoch: 013/050 | Batch 0009/0018 | Loss: 0.1764
# Epoch: 013/050 | Batch 0012/0018 | Loss: 0.1280
# Epoch: 013/050 | Batch 0015/0018 | Loss: 0.1151
# Epoch: 013/050 | Train: 92.10% | Validation: 86.00%
# Time elapsed: 5.46 min
# Epoch: 014/050 | Batch 0000/0018 | Loss: 0.1301
# Epoch: 014/050 | Batch 0003/0018 | Loss: 0.1078
# Epoch: 014/050 | Batch 0006/0018 | Loss: 0.1079
# Epoch: 014/050 | Batch 0009/0018 | Loss: 0.0913
# Epoch: 014/050 | Batch 0012/0018 | Loss: 0.0906
# Epoch: 014/050 | Batch 0015/0018 | Loss: 0.0618
# Epoch: 014/050 | Train: 94.86% | Validation: 85.87%
# Time elapsed: 5.88 min
# Epoch: 015/050 | Batch 0000/0018 | Loss: 0.0957
# Epoch: 015/050 | Batch 0003/0018 | Loss: 0.1112
# Epoch: 015/050 | Batch 0006/0018 | Loss: 0.0967
# Epoch: 015/050 | Batch 0009/0018 | Loss: 0.1262
# Epoch: 015/050 | Batch 0012/0018 | Loss: 0.0814
# Epoch: 015/050 | Batch 0015/0018 | Loss: 0.0691
# Epoch: 015/050 | Train: 90.55% | Validation: 81.64%
# Time elapsed: 6.30 min
# Epoch: 016/050 | Batch 0000/0018 | Loss: 0.1317
# Epoch: 016/050 | Batch 0003/0018 | Loss: 0.0844
# Epoch: 016/050 | Batch 0006/0018 | Loss: 0.0829
# Epoch: 016/050 | Batch 0009/0018 | Loss: 0.2091
# Epoch: 016/050 | Batch 0012/0018 | Loss: 0.1575
# Epoch: 016/050 | Batch 0015/0018 | Loss: 0.1044
# Epoch: 016/050 | Train: 90.62% | Validation: 82.83%
# Time elapsed: 6.74 min
# Epoch: 017/050 | Batch 0000/0018 | Loss: 0.1183
# Epoch: 017/050 | Batch 0003/0018 | Loss: 0.1033
# Epoch: 017/050 | Batch 0006/0018 | Loss: 0.1533
# Epoch: 017/050 | Batch 0009/0018 | Loss: 0.1073
# Epoch: 017/050 | Batch 0012/0018 | Loss: 0.1424
# Epoch: 017/050 | Batch 0015/0018 | Loss: 0.1297
# Epoch: 017/050 | Train: 93.80% | Validation: 85.87%
# Time elapsed: 7.17 min
# Epoch: 018/050 | Batch 0000/0018 | Loss: 0.1340
# Epoch: 018/050 | Batch 0003/0018 | Loss: 0.0665
# Epoch: 018/050 | Batch 0006/0018 | Loss: 0.2016
# Epoch: 018/050 | Batch 0009/0018 | Loss: 0.2115
# Epoch: 018/050 | Batch 0012/0018 | Loss: 0.0698
# Epoch: 018/050 | Batch 0015/0018 | Loss: 0.1308
# Epoch: 018/050 | Train: 86.91% | Validation: 79.92%
# Time elapsed: 7.61 min
# Epoch: 019/050 | Batch 0000/0018 | Loss: 0.1275
# Epoch: 019/050 | Batch 0003/0018 | Loss: 0.0900
# Epoch: 019/050 | Batch 0006/0018 | Loss: 0.1183
# Epoch: 019/050 | Batch 0009/0018 | Loss: 0.1334
# Epoch: 019/050 | Batch 0012/0018 | Loss: 0.1452
# Epoch: 019/050 | Batch 0015/0018 | Loss: 0.0784
# Epoch: 019/050 | Train: 93.69% | Validation: 85.60%
# Time elapsed: 8.04 min
# Epoch: 020/050 | Batch 0000/0018 | Loss: 0.1162
# Epoch: 020/050 | Batch 0003/0018 | Loss: 0.0475
# Epoch: 020/050 | Batch 0006/0018 | Loss: 0.0723
# Epoch: 020/050 | Batch 0009/0018 | Loss: 0.1029
# Epoch: 020/050 | Batch 0012/0018 | Loss: 0.0921
# Epoch: 020/050 | Batch 0015/0018 | Loss: 0.0548
# Epoch: 020/050 | Train: 92.89% | Validation: 83.49%
# Time elapsed: 8.48 min
# Epoch: 021/050 | Batch 0000/0018 | Loss: 0.1069
# Epoch: 021/050 | Batch 0003/0018 | Loss: 0.0742
# Epoch: 021/050 | Batch 0006/0018 | Loss: 0.0458
# Epoch: 021/050 | Batch 0009/0018 | Loss: 0.0856
# Epoch: 021/050 | Batch 0012/0018 | Loss: 0.1064
# Epoch: 021/050 | Batch 0015/0018 | Loss: 0.0778
# Epoch: 021/050 | Train: 93.36% | Validation: 82.43%
# Time elapsed: 8.92 min
# Epoch: 022/050 | Batch 0000/0018 | Loss: 0.0839
# Epoch: 022/050 | Batch 0003/0018 | Loss: 0.0491
# Epoch: 022/050 | Batch 0006/0018 | Loss: 0.0548
# Epoch: 022/050 | Batch 0009/0018 | Loss: 0.0527
# Epoch: 022/050 | Batch 0012/0018 | Loss: 0.0668
# Epoch: 022/050 | Batch 0015/0018 | Loss: 0.0585
# Epoch: 022/050 | Train: 95.89% | Validation: 86.13%
# Time elapsed: 9.37 min
# Epoch: 023/050 | Batch 0000/0018 | Loss: 0.0343
# Epoch: 023/050 | Batch 0003/0018 | Loss: 0.0681
# Epoch: 023/050 | Batch 0006/0018 | Loss: 0.0282
# Epoch: 023/050 | Batch 0009/0018 | Loss: 0.0641
# Epoch: 023/050 | Batch 0012/0018 | Loss: 0.1014
# Epoch: 023/050 | Batch 0015/0018 | Loss: 0.0230
# Epoch: 023/050 | Train: 85.37% | Validation: 80.71%
# Time elapsed: 9.80 min
# Epoch: 024/050 | Batch 0000/0018 | Loss: 0.1406
# Epoch: 024/050 | Batch 0003/0018 | Loss: 0.0687
# Epoch: 024/050 | Batch 0006/0018 | Loss: 0.0470
# Epoch: 024/050 | Batch 0009/0018 | Loss: 0.0935
# Epoch: 024/050 | Batch 0012/0018 | Loss: 0.0469
# Epoch: 024/050 | Batch 0015/0018 | Loss: 0.0601
# Epoch: 024/050 | Train: 96.76% | Validation: 86.53%
# Time elapsed: 10.25 min
# Epoch: 025/050 | Batch 0000/0018 | Loss: 0.0403
# Epoch: 025/050 | Batch 0003/0018 | Loss: 0.0442
# Epoch: 025/050 | Batch 0006/0018 | Loss: 0.0934
# Epoch: 025/050 | Batch 0009/0018 | Loss: 0.0806
# Epoch: 025/050 | Batch 0012/0018 | Loss: 0.1003
# Epoch: 025/050 | Batch 0015/0018 | Loss: 0.1362
# Epoch: 025/050 | Train: 97.88% | Validation: 88.51%
# Time elapsed: 10.68 min
# Epoch: 026/050 | Batch 0000/0018 | Loss: 0.0408
# Epoch: 026/050 | Batch 0003/0018 | Loss: 0.0987
# Epoch: 026/050 | Batch 0006/0018 | Loss: 0.0898
# Epoch: 026/050 | Batch 0009/0018 | Loss: 0.0440
# Epoch: 026/050 | Batch 0012/0018 | Loss: 0.1315
# Epoch: 026/050 | Batch 0015/0018 | Loss: 0.0557
# Epoch: 026/050 | Train: 95.06% | Validation: 85.34%
# Time elapsed: 11.12 min
# Epoch: 027/050 | Batch 0000/0018 | Loss: 0.0822
# Epoch: 027/050 | Batch 0003/0018 | Loss: 0.0633
# Epoch: 027/050 | Batch 0006/0018 | Loss: 0.0557
# Epoch: 027/050 | Batch 0009/0018 | Loss: 0.0474
# Epoch: 027/050 | Batch 0012/0018 | Loss: 0.0505
# Epoch: 027/050 | Batch 0015/0018 | Loss: 0.0867
# Epoch: 027/050 | Train: 97.44% | Validation: 86.00%
# Time elapsed: 11.55 min
# Epoch: 028/050 | Batch 0000/0018 | Loss: 0.0460
# Epoch: 028/050 | Batch 0003/0018 | Loss: 0.0297
# Epoch: 028/050 | Batch 0006/0018 | Loss: 0.0714
# Epoch: 028/050 | Batch 0009/0018 | Loss: 0.0569
# Epoch: 028/050 | Batch 0012/0018 | Loss: 0.0269
# Epoch: 028/050 | Batch 0015/0018 | Loss: 0.0482
# Epoch: 028/050 | Train: 94.15% | Validation: 82.43%
# Time elapsed: 12.03 min
# Epoch: 029/050 | Batch 0000/0018 | Loss: 0.0328
# Epoch: 029/050 | Batch 0003/0018 | Loss: 0.0196
# Epoch: 029/050 | Batch 0006/0018 | Loss: 0.0238
# Epoch: 029/050 | Batch 0009/0018 | Loss: 0.0533
# Epoch: 029/050 | Batch 0012/0018 | Loss: 0.0197
# Epoch: 029/050 | Batch 0015/0018 | Loss: 0.0155
# Epoch: 029/050 | Train: 98.59% | Validation: 86.66%
# Time elapsed: 12.45 min
# Epoch: 030/050 | Batch 0000/0018 | Loss: 0.0251
# Epoch: 030/050 | Batch 0003/0018 | Loss: 0.0195
# Epoch: 030/050 | Batch 0006/0018 | Loss: 0.0235
# Epoch: 030/050 | Batch 0009/0018 | Loss: 0.0144
# Epoch: 030/050 | Batch 0012/0018 | Loss: 0.0215
# Epoch: 030/050 | Batch 0015/0018 | Loss: 0.0038
# Epoch: 030/050 | Train: 99.07% | Validation: 87.58%
# Time elapsed: 12.89 min
# Epoch: 031/050 | Batch 0000/0018 | Loss: 0.0242
# Epoch: 031/050 | Batch 0003/0018 | Loss: 0.0045
# Epoch: 031/050 | Batch 0006/0018 | Loss: 0.0121
# Epoch: 031/050 | Batch 0009/0018 | Loss: 0.0257
# Epoch: 031/050 | Batch 0012/0018 | Loss: 0.0136
# Epoch: 031/050 | Batch 0015/0018 | Loss: 0.0058
# Epoch: 031/050 | Train: 98.54% | Validation: 87.19%
# Time elapsed: 13.32 min
# Epoch: 032/050 | Batch 0000/0018 | Loss: 0.0050
# Epoch: 032/050 | Batch 0003/0018 | Loss: 0.0252
# Epoch: 032/050 | Batch 0006/0018 | Loss: 0.0100
# Epoch: 032/050 | Batch 0009/0018 | Loss: 0.0465
# Epoch: 032/050 | Batch 0012/0018 | Loss: 0.0101
# Epoch: 032/050 | Batch 0015/0018 | Loss: 0.0089
# Epoch: 032/050 | Train: 98.76% | Validation: 86.53%
# Time elapsed: 13.74 min
# Epoch: 033/050 | Batch 0000/0018 | Loss: 0.0086
# Epoch: 033/050 | Batch 0003/0018 | Loss: 0.0034
# Epoch: 033/050 | Batch 0006/0018 | Loss: 0.0056
# Epoch: 033/050 | Batch 0009/0018 | Loss: 0.0156
# Epoch: 033/050 | Batch 0012/0018 | Loss: 0.0118
# Epoch: 033/050 | Batch 0015/0018 | Loss: 0.0497
# Epoch: 033/050 | Train: 97.22% | Validation: 86.00%
# Time elapsed: 14.15 min
# Epoch: 034/050 | Batch 0000/0018 | Loss: 0.0036
# Epoch: 034/050 | Batch 0003/0018 | Loss: 0.0142
# Epoch: 034/050 | Batch 0006/0018 | Loss: 0.0267
# Epoch: 034/050 | Batch 0009/0018 | Loss: 0.0277
# Epoch: 034/050 | Batch 0012/0018 | Loss: 0.0154
# Epoch: 034/050 | Batch 0015/0018 | Loss: 0.0122
# Epoch: 034/050 | Train: 94.61% | Validation: 85.47%
# Time elapsed: 14.55 min
# Epoch: 035/050 | Batch 0000/0018 | Loss: 0.0378
# Epoch: 035/050 | Batch 0003/0018 | Loss: 0.0022
# Epoch: 035/050 | Batch 0006/0018 | Loss: 0.0305
# Epoch: 035/050 | Batch 0009/0018 | Loss: 0.0463
# Epoch: 035/050 | Batch 0012/0018 | Loss: 0.0292
# Epoch: 035/050 | Batch 0015/0018 | Loss: 0.0039
# Epoch: 035/050 | Train: 98.23% | Validation: 87.71%
# Time elapsed: 14.97 min
# Epoch: 036/050 | Batch 0000/0018 | Loss: 0.0175
# Epoch: 036/050 | Batch 0003/0018 | Loss: 0.0289
# Epoch: 036/050 | Batch 0006/0018 | Loss: 0.0046
# Epoch: 036/050 | Batch 0009/0018 | Loss: 0.0250
# Epoch: 036/050 | Batch 0012/0018 | Loss: 0.0074
# Epoch: 036/050 | Batch 0015/0018 | Loss: 0.0145
# Epoch: 036/050 | Train: 98.52% | Validation: 86.66%
# Time elapsed: 15.43 min
# Epoch: 037/050 | Batch 0000/0018 | Loss: 0.0021
# Epoch: 037/050 | Batch 0003/0018 | Loss: 0.0203
# Epoch: 037/050 | Batch 0006/0018 | Loss: 0.0166
# Epoch: 037/050 | Batch 0009/0018 | Loss: 0.0061
# Epoch: 037/050 | Batch 0012/0018 | Loss: 0.0141
# Epoch: 037/050 | Batch 0015/0018 | Loss: 0.0138
# Epoch: 037/050 | Train: 99.18% | Validation: 88.11%
# Time elapsed: 15.87 min
# Epoch: 038/050 | Batch 0000/0018 | Loss: 0.0120
# Epoch: 038/050 | Batch 0003/0018 | Loss: 0.0041
# Epoch: 038/050 | Batch 0006/0018 | Loss: 0.0015
# Epoch: 038/050 | Batch 0009/0018 | Loss: 0.0049
# Epoch: 038/050 | Batch 0012/0018 | Loss: 0.0301
# Epoch: 038/050 | Batch 0015/0018 | Loss: 0.0021
# Epoch: 038/050 | Train: 99.07% | Validation: 86.13%
# Time elapsed: 16.30 min
# Epoch: 039/050 | Batch 0000/0018 | Loss: 0.0068
# Epoch: 039/050 | Batch 0003/0018 | Loss: 0.0193
# Epoch: 039/050 | Batch 0006/0018 | Loss: 0.0053
# Epoch: 039/050 | Batch 0009/0018 | Loss: 0.0029
# Epoch: 039/050 | Batch 0012/0018 | Loss: 0.0140
# Epoch: 039/050 | Batch 0015/0018 | Loss: 0.0103
# Epoch: 039/050 | Train: 99.82% | Validation: 87.45%
# Time elapsed: 16.72 min
# Epoch: 040/050 | Batch 0000/0018 | Loss: 0.0010
# Epoch: 040/050 | Batch 0003/0018 | Loss: 0.0057
# Epoch: 040/050 | Batch 0006/0018 | Loss: 0.0088
# Epoch: 040/050 | Batch 0009/0018 | Loss: 0.0026
# Epoch: 040/050 | Batch 0012/0018 | Loss: 0.0168
# Epoch: 040/050 | Batch 0015/0018 | Loss: 0.0185
# Epoch: 040/050 | Train: 99.82% | Validation: 87.98%
# Time elapsed: 17.16 min
# Epoch: 041/050 | Batch 0000/0018 | Loss: 0.0127
# Epoch: 041/050 | Batch 0003/0018 | Loss: 0.0123
# Epoch: 041/050 | Batch 0006/0018 | Loss: 0.0330
# Epoch: 041/050 | Batch 0009/0018 | Loss: 0.0130
# Epoch: 041/050 | Batch 0012/0018 | Loss: 0.0057
# Epoch: 041/050 | Batch 0015/0018 | Loss: 0.0146
# Epoch: 041/050 | Train: 99.80% | Validation: 87.05%
# Time elapsed: 17.58 min
# Epoch: 042/050 | Batch 0000/0018 | Loss: 0.0022
# Epoch: 042/050 | Batch 0003/0018 | Loss: 0.0071
# Epoch: 042/050 | Batch 0006/0018 | Loss: 0.0090
# Epoch: 042/050 | Batch 0009/0018 | Loss: 0.0169
# Epoch: 042/050 | Batch 0012/0018 | Loss: 0.0033
# Epoch: 042/050 | Batch 0015/0018 | Loss: 0.0032
# Epoch: 042/050 | Train: 99.43% | Validation: 85.73%
# Time elapsed: 17.99 min
# Epoch: 043/050 | Batch 0000/0018 | Loss: 0.0051
# Epoch: 043/050 | Batch 0003/0018 | Loss: 0.0046
# Epoch: 043/050 | Batch 0006/0018 | Loss: 0.0039
# Epoch: 043/050 | Batch 0009/0018 | Loss: 0.0113
# Epoch: 043/050 | Batch 0012/0018 | Loss: 0.0338
# Epoch: 043/050 | Batch 0015/0018 | Loss: 0.0027
# Epoch: 043/050 | Train: 98.83% | Validation: 85.87%
# Time elapsed: 18.41 min
# Epoch: 044/050 | Batch 0000/0018 | Loss: 0.0022
# Epoch: 044/050 | Batch 0003/0018 | Loss: 0.0071
# Epoch: 044/050 | Batch 0006/0018 | Loss: 0.0038
# Epoch: 044/050 | Batch 0009/0018 | Loss: 0.0084
# Epoch: 044/050 | Batch 0012/0018 | Loss: 0.0244
# Epoch: 044/050 | Batch 0015/0018 | Loss: 0.0031
# Epoch: 044/050 | Train: 99.87% | Validation: 87.45%
# Time elapsed: 18.81 min
# Epoch: 045/050 | Batch 0000/0018 | Loss: 0.0026
# Epoch: 045/050 | Batch 0003/0018 | Loss: 0.0024
# Epoch: 045/050 | Batch 0006/0018 | Loss: 0.0014
# Epoch: 045/050 | Batch 0009/0018 | Loss: 0.0042
# Epoch: 045/050 | Batch 0012/0018 | Loss: 0.0009
# Epoch: 045/050 | Batch 0015/0018 | Loss: 0.0026
# Epoch: 045/050 | Train: 99.87% | Validation: 88.90%
# Time elapsed: 19.22 min
# Epoch: 046/050 | Batch 0000/0018 | Loss: 0.0028
# Epoch: 046/050 | Batch 0003/0018 | Loss: 0.0100
# Epoch: 046/050 | Batch 0006/0018 | Loss: 0.0006
# Epoch: 046/050 | Batch 0009/0018 | Loss: 0.0005
# Epoch: 046/050 | Batch 0012/0018 | Loss: 0.0003
# Epoch: 046/050 | Batch 0015/0018 | Loss: 0.0004
# Epoch: 046/050 | Train: 100.00% | Validation: 87.98%
# Time elapsed: 19.65 min
# Epoch: 047/050 | Batch 0000/0018 | Loss: 0.0007
# Epoch: 047/050 | Batch 0003/0018 | Loss: 0.0021
# Epoch: 047/050 | Batch 0006/0018 | Loss: 0.0023
# Epoch: 047/050 | Batch 0009/0018 | Loss: 0.0004
# Epoch: 047/050 | Batch 0012/0018 | Loss: 0.0002
# Epoch: 047/050 | Batch 0015/0018 | Loss: 0.0003
# Epoch: 047/050 | Train: 100.00% | Validation: 88.11%
# Time elapsed: 20.07 min
# Epoch: 048/050 | Batch 0000/0018 | Loss: 0.0003
# Epoch: 048/050 | Batch 0003/0018 | Loss: 0.0002
# Epoch: 048/050 | Batch 0006/0018 | Loss: 0.0002
# Epoch: 048/050 | Batch 0009/0018 | Loss: 0.0003
# Epoch: 048/050 | Batch 0012/0018 | Loss: 0.0001
# Epoch: 048/050 | Batch 0015/0018 | Loss: 0.0002
# Epoch: 048/050 | Train: 100.00% | Validation: 87.98%
# Time elapsed: 20.49 min
# Epoch: 049/050 | Batch 0000/0018 | Loss: 0.0002
# Epoch: 049/050 | Batch 0003/0018 | Loss: 0.0002
# Epoch: 049/050 | Batch 0006/0018 | Loss: 0.0002
# Epoch: 049/050 | Batch 0009/0018 | Loss: 0.0003
# Epoch: 049/050 | Batch 0012/0018 | Loss: 0.0001
# Epoch: 049/050 | Batch 0015/0018 | Loss: 0.0002
# Epoch: 049/050 | Train: 100.00% | Validation: 88.11%
# Time elapsed: 20.91 min
# Epoch: 050/050 | Batch 0000/0018 | Loss: 0.0002
# Epoch: 050/050 | Batch 0003/0018 | Loss: 0.0002
# Epoch: 050/050 | Batch 0006/0018 | Loss: 0.0002
# Epoch: 050/050 | Batch 0009/0018 | Loss: 0.0002
# Epoch: 050/050 | Batch 0012/0018 | Loss: 0.0001
# Epoch: 050/050 | Batch 0015/0018 | Loss: 0.0002
# Epoch: 050/050 | Train: 100.00% | Validation: 88.11%
# Time elapsed: 21.36 min
# Total Training Time: 21.36 min
# Test accuracy 86.00%

# %%
torch.save(model.state_dict(), 'LeNet5_model.pt')
torch.save(optimizer.state_dict(), 'LeNet5_optimizer.pt')
torch.save(scheduler.state_dict(), 'LeNet5_scheduler.pt')
