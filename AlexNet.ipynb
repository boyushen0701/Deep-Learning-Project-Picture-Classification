# %% [markdown]
# # AlexNet

# %% [markdown]
# ### Settings

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import os
from helper_evaluation import set_all_seeds, set_deterministic
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples

RANDOM_SEED = 1
BATCH_SIZE = 256
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Data Loading

# %%
# Set random seed
set_all_seeds(RANDOM_SEED)
set_deterministic()

transform = torchvision.transforms.Compose([
        torchvision.transforms.Resize((64,64)),
        torchvision.transforms.ToTensor(), 
        torchvision.transforms.Normalize((0.5,),(0.5,)) # （0.5,0.5,0.5）
    ])

# Load images 
dataset_dir = './data'
dataset = torchvision.datasets.ImageFolder(root = dataset_dir, transform = transform)

# Determine sizes of the training set and the test set
total_size = len(dataset)
train_size = int(np.floor(total_size * 0.6))
test_size = int(np.floor(total_size * 0.3))
valid_size = total_size - test_size - train_size

# %%
# Split the entire dataset into 60% of training set, 30% of test set, and 10% validation set.
training_dataset, test_dataset, valid_dataset = torch.utils.data.random_split(dataset, [train_size, test_size, valid_size])

# %%
# Loaders
train_loader = torch.utils.data.DataLoader(training_dataset, batch_size = BATCH_SIZE, shuffle = False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle = False)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size = BATCH_SIZE, shuffle = False)

# %% [markdown]
# ### Model

# %%
class AlexNet(torch.nn.Module):
    def __init__(self, num_classes, grayscale = False):
        super().__init__()
        self.grayscale = grayscale
        self.num_classes = num_classes
        
        if self.grayscale:
            in_channels = 1
        else:
            in_channels = 3
        
        self.features = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels, 64, kernel_size = 11, stride = 4, padding = 2),
            torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(inplace = True),
            torch.nn.MaxPool2d(kernel_size =3, stride = 2),
            
            torch.nn.Conv2d(64,192,kernel_size = 5, padding = 2),
            torch.nn.BatchNorm2d(192),
            torch.nn.ReLU(inplace = True),
            torch.nn.MaxPool2d(kernel_size = 3, stride = 2),
            
            torch.nn.Conv2d(192,384,kernel_size = 3, padding = 1),
            torch.nn.BatchNorm2d(384),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Conv2d(384,256,kernel_size = 3, padding = 1),
            torch.nn.BatchNorm2d(256),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Conv2d(256,256,kernel_size = 3, padding = 1),
            torch.nn.BatchNorm2d(256),
            torch.nn.ReLU(inplace = True),
            torch.nn.MaxPool2d(kernel_size = 3, stride = 2),
        )
        self.avgpool = torch.nn.AdaptiveAvgPool2d((6,6))
        self.classifier = torch.nn.Sequential(
            torch.nn.Dropout(0.5),
            torch.nn.Linear(256*6*6, 4096),
            torch.nn.BatchNorm1d(4096),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Dropout(0.5),
            torch.nn.Linear(4096,4096),     
            torch.nn.BatchNorm1d(4096),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Linear(4096,num_classes)
        )
        
    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), 256*6*6)
        logits = self.classifier(x)
        return logits

# %%
model = AlexNet(num_classes = 2)
model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr = 0.1, momentum = 0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.1,
                                                       mode='max',
                                                       verbose=True)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    test_loader=test_loader,
    valid_loader = valid_loader,
    optimizer=optimizer,
    device=DEVICE,
    logging_interval=3)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=100)
plt.savefig('AlexNet_training_loss.png')
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([80, 100])
plt.savefig('AlexNet_accuracy.png')
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0018 | Loss: 0.7837
# Epoch: 001/050 | Batch 0003/0018 | Loss: 4.7253
# Epoch: 001/050 | Batch 0006/0018 | Loss: 7.3198
# Epoch: 001/050 | Batch 0009/0018 | Loss: 5.8003
# Epoch: 001/050 | Batch 0012/0018 | Loss: 4.2658
# d:\users\asus\appdata\local\programs\python\python39\lib\site-packages\PIL\Image.py:951: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch: 001/050 | Batch 0015/0018 | Loss: 3.4240
# Epoch: 001/050 | Train: 55.75% | Validation: 56.80%
# Time elapsed: 0.86 min
# Epoch: 002/050 | Batch 0000/0018 | Loss: 0.4920
# Epoch: 002/050 | Batch 0003/0018 | Loss: 0.7764
# Epoch: 002/050 | Batch 0006/0018 | Loss: 0.9675
# Epoch: 002/050 | Batch 0009/0018 | Loss: 0.8276
# Epoch: 002/050 | Batch 0012/0018 | Loss: 0.5322
# Epoch: 002/050 | Batch 0015/0018 | Loss: 0.5071
# Epoch: 002/050 | Train: 87.71% | Validation: 87.58%
# Time elapsed: 1.70 min
# Epoch: 003/050 | Batch 0000/0018 | Loss: 0.2868
# Epoch: 003/050 | Batch 0003/0018 | Loss: 0.3898
# Epoch: 003/050 | Batch 0006/0018 | Loss: 1.0559
# Epoch: 003/050 | Batch 0009/0018 | Loss: 0.5393
# Epoch: 003/050 | Batch 0012/0018 | Loss: 0.2933
# Epoch: 003/050 | Batch 0015/0018 | Loss: 0.2303
# Epoch: 003/050 | Train: 88.30% | Validation: 89.17%
# Time elapsed: 2.61 min
# Epoch: 004/050 | Batch 0000/0018 | Loss: 0.2543
# Epoch: 004/050 | Batch 0003/0018 | Loss: 0.3265
# Epoch: 004/050 | Batch 0006/0018 | Loss: 0.5894
# Epoch: 004/050 | Batch 0009/0018 | Loss: 0.3966
# Epoch: 004/050 | Batch 0012/0018 | Loss: 0.2333
# Epoch: 004/050 | Batch 0015/0018 | Loss: 0.4839
# Epoch: 004/050 | Train: 73.18% | Validation: 70.67%
# Time elapsed: 3.56 min
# Epoch: 005/050 | Batch 0000/0018 | Loss: 0.6628
# Epoch: 005/050 | Batch 0003/0018 | Loss: 0.8050
# Epoch: 005/050 | Batch 0006/0018 | Loss: 0.4738
# Epoch: 005/050 | Batch 0009/0018 | Loss: 0.5867
# Epoch: 005/050 | Batch 0012/0018 | Loss: 0.3061
# Epoch: 005/050 | Batch 0015/0018 | Loss: 0.3187
# Epoch: 005/050 | Train: 90.27% | Validation: 88.38%
# Time elapsed: 4.74 min
# Epoch: 006/050 | Batch 0000/0018 | Loss: 0.2406
# Epoch: 006/050 | Batch 0003/0018 | Loss: 0.3190
# Epoch: 006/050 | Batch 0006/0018 | Loss: 0.3027
# Epoch: 006/050 | Batch 0009/0018 | Loss: 0.2498
# Epoch: 006/050 | Batch 0012/0018 | Loss: 0.2035
# Epoch: 006/050 | Batch 0015/0018 | Loss: 0.2101
# Epoch: 006/050 | Train: 90.44% | Validation: 88.64%
# Time elapsed: 5.94 min
# Epoch: 007/050 | Batch 0000/0018 | Loss: 0.2432
# Epoch: 007/050 | Batch 0003/0018 | Loss: 0.2943
# Epoch: 007/050 | Batch 0006/0018 | Loss: 0.2248
# Epoch: 007/050 | Batch 0009/0018 | Loss: 0.2063
# Epoch: 007/050 | Batch 0012/0018 | Loss: 0.1649
# Epoch: 007/050 | Batch 0015/0018 | Loss: 0.2140
# Epoch: 007/050 | Train: 88.85% | Validation: 87.19%
# Time elapsed: 7.00 min
# Epoch: 008/050 | Batch 0000/0018 | Loss: 0.2718
# Epoch: 008/050 | Batch 0003/0018 | Loss: 0.2455
# Epoch: 008/050 | Batch 0006/0018 | Loss: 0.2071
# Epoch: 008/050 | Batch 0009/0018 | Loss: 0.2084
# Epoch: 008/050 | Batch 0012/0018 | Loss: 0.1638
# Epoch: 008/050 | Batch 0015/0018 | Loss: 0.2082
# Epoch: 008/050 | Train: 92.05% | Validation: 90.36%
# Time elapsed: 8.15 min
# Epoch: 009/050 | Batch 0000/0018 | Loss: 0.1901
# Epoch: 009/050 | Batch 0003/0018 | Loss: 0.1896
# Epoch: 009/050 | Batch 0006/0018 | Loss: 0.2176
# Epoch: 009/050 | Batch 0009/0018 | Loss: 0.1466
# Epoch: 009/050 | Batch 0012/0018 | Loss: 0.1562
# Epoch: 009/050 | Batch 0015/0018 | Loss: 0.1642
# Epoch: 009/050 | Train: 93.36% | Validation: 91.28%
# Time elapsed: 9.28 min
# Epoch: 010/050 | Batch 0000/0018 | Loss: 0.1699
# Epoch: 010/050 | Batch 0003/0018 | Loss: 0.1792
# Epoch: 010/050 | Batch 0006/0018 | Loss: 0.2196
# Epoch: 010/050 | Batch 0009/0018 | Loss: 0.1353
# Epoch: 010/050 | Batch 0012/0018 | Loss: 0.1526
# Epoch: 010/050 | Batch 0015/0018 | Loss: 0.1358
# Epoch: 010/050 | Train: 94.04% | Validation: 91.41%
# Time elapsed: 10.30 min
# Epoch: 011/050 | Batch 0000/0018 | Loss: 0.1472
# Epoch: 011/050 | Batch 0003/0018 | Loss: 0.1686
# Epoch: 011/050 | Batch 0006/0018 | Loss: 0.1836
# Epoch: 011/050 | Batch 0009/0018 | Loss: 0.1378
# Epoch: 011/050 | Batch 0012/0018 | Loss: 0.1525
# Epoch: 011/050 | Batch 0015/0018 | Loss: 0.1184
# Epoch: 011/050 | Train: 94.55% | Validation: 92.73%
# Time elapsed: 11.33 min
# Epoch: 012/050 | Batch 0000/0018 | Loss: 0.1270
# Epoch: 012/050 | Batch 0003/0018 | Loss: 0.1425
# Epoch: 012/050 | Batch 0006/0018 | Loss: 0.1846
# Epoch: 012/050 | Batch 0009/0018 | Loss: 0.1102
# Epoch: 012/050 | Batch 0012/0018 | Loss: 0.1365
# Epoch: 012/050 | Batch 0015/0018 | Loss: 0.1064
# Epoch: 012/050 | Train: 94.24% | Validation: 92.07%
# Time elapsed: 12.36 min
# Epoch: 013/050 | Batch 0000/0018 | Loss: 0.1327
# Epoch: 013/050 | Batch 0003/0018 | Loss: 0.1472
# Epoch: 013/050 | Batch 0006/0018 | Loss: 0.1563
# Epoch: 013/050 | Batch 0009/0018 | Loss: 0.0966
# Epoch: 013/050 | Batch 0012/0018 | Loss: 0.1344
# Epoch: 013/050 | Batch 0015/0018 | Loss: 0.0921
# Epoch: 013/050 | Train: 95.76% | Validation: 92.21%
# Time elapsed: 13.42 min
# Epoch: 014/050 | Batch 0000/0018 | Loss: 0.1126
# Epoch: 014/050 | Batch 0003/0018 | Loss: 0.1352
# Epoch: 014/050 | Batch 0006/0018 | Loss: 0.1453
# Epoch: 014/050 | Batch 0009/0018 | Loss: 0.1041
# Epoch: 014/050 | Batch 0012/0018 | Loss: 0.1379
# Epoch: 014/050 | Batch 0015/0018 | Loss: 0.0704
# Epoch: 014/050 | Train: 96.60% | Validation: 93.39%
# Time elapsed: 14.46 min
# Epoch: 015/050 | Batch 0000/0018 | Loss: 0.1150
# Epoch: 015/050 | Batch 0003/0018 | Loss: 0.1235
# Epoch: 015/050 | Batch 0006/0018 | Loss: 0.1225
# Epoch: 015/050 | Batch 0009/0018 | Loss: 0.0916
# Epoch: 015/050 | Batch 0012/0018 | Loss: 0.1339
# Epoch: 015/050 | Batch 0015/0018 | Loss: 0.0569
# Epoch: 015/050 | Train: 96.29% | Validation: 93.13%
# Time elapsed: 15.49 min
# Epoch: 016/050 | Batch 0000/0018 | Loss: 0.0904
# Epoch: 016/050 | Batch 0003/0018 | Loss: 0.1028
# Epoch: 016/050 | Batch 0006/0018 | Loss: 0.0931
# Epoch: 016/050 | Batch 0009/0018 | Loss: 0.0992
# Epoch: 016/050 | Batch 0012/0018 | Loss: 0.1076
# Epoch: 016/050 | Batch 0015/0018 | Loss: 0.0284
# Epoch: 016/050 | Train: 96.18% | Validation: 94.06%
# Time elapsed: 16.54 min
# Epoch: 017/050 | Batch 0000/0018 | Loss: 0.0982
# Epoch: 017/050 | Batch 0003/0018 | Loss: 0.1057
# Epoch: 017/050 | Batch 0006/0018 | Loss: 0.0863
# Epoch: 017/050 | Batch 0009/0018 | Loss: 0.0819
# Epoch: 017/050 | Batch 0012/0018 | Loss: 0.0755
# Epoch: 017/050 | Batch 0015/0018 | Loss: 0.0539
# Epoch: 017/050 | Train: 95.12% | Validation: 93.79%
# Time elapsed: 17.58 min
# Epoch: 018/050 | Batch 0000/0018 | Loss: 0.0621
# Epoch: 018/050 | Batch 0003/0018 | Loss: 0.1377
# Epoch: 018/050 | Batch 0006/0018 | Loss: 0.1028
# Epoch: 018/050 | Batch 0009/0018 | Loss: 0.0749
# Epoch: 018/050 | Batch 0012/0018 | Loss: 0.0809
# Epoch: 018/050 | Batch 0015/0018 | Loss: 0.0481
# Epoch: 018/050 | Train: 97.77% | Validation: 93.53%
# Time elapsed: 18.66 min
# Epoch: 019/050 | Batch 0000/0018 | Loss: 0.0632
# Epoch: 019/050 | Batch 0003/0018 | Loss: 0.0922
# Epoch: 019/050 | Batch 0006/0018 | Loss: 0.0703
# Epoch: 019/050 | Batch 0009/0018 | Loss: 0.0499
# Epoch: 019/050 | Batch 0012/0018 | Loss: 0.1073
# Epoch: 019/050 | Batch 0015/0018 | Loss: 0.0325
# Epoch: 019/050 | Train: 93.47% | Validation: 89.83%
# Time elapsed: 19.75 min
# Epoch: 020/050 | Batch 0000/0018 | Loss: 0.0881
# Epoch: 020/050 | Batch 0003/0018 | Loss: 0.1085
# Epoch: 020/050 | Batch 0006/0018 | Loss: 0.0636
# Epoch: 020/050 | Batch 0009/0018 | Loss: 0.0780
# Epoch: 020/050 | Batch 0012/0018 | Loss: 0.0718
# Epoch: 020/050 | Batch 0015/0018 | Loss: 0.0323
# Epoch: 020/050 | Train: 95.45% | Validation: 90.89%
# Time elapsed: 20.79 min
# Epoch: 021/050 | Batch 0000/0018 | Loss: 0.1188
# Epoch: 021/050 | Batch 0003/0018 | Loss: 0.0491
# Epoch: 021/050 | Batch 0006/0018 | Loss: 0.0679
# Epoch: 021/050 | Batch 0009/0018 | Loss: 0.0634
# Epoch: 021/050 | Batch 0012/0018 | Loss: 0.0518
# Epoch: 021/050 | Batch 0015/0018 | Loss: 0.0234
# Epoch: 021/050 | Train: 96.89% | Validation: 94.98%
# Time elapsed: 21.80 min
# Epoch: 022/050 | Batch 0000/0018 | Loss: 0.0325
# Epoch: 022/050 | Batch 0003/0018 | Loss: 0.0368
# Epoch: 022/050 | Batch 0006/0018 | Loss: 0.0487
# Epoch: 022/050 | Batch 0009/0018 | Loss: 0.0488
# Epoch: 022/050 | Batch 0012/0018 | Loss: 0.0628
# Epoch: 022/050 | Batch 0015/0018 | Loss: 0.0203
# Epoch: 022/050 | Train: 95.28% | Validation: 93.13%
# Time elapsed: 22.80 min
# Epoch: 023/050 | Batch 0000/0018 | Loss: 0.0642
# Epoch: 023/050 | Batch 0003/0018 | Loss: 0.0514
# Epoch: 023/050 | Batch 0006/0018 | Loss: 0.0680
# Epoch: 023/050 | Batch 0009/0018 | Loss: 0.0565
# Epoch: 023/050 | Batch 0012/0018 | Loss: 0.0548
# Epoch: 023/050 | Batch 0015/0018 | Loss: 0.0129
# Epoch: 023/050 | Train: 96.05% | Validation: 91.81%
# Time elapsed: 23.91 min
# Epoch: 024/050 | Batch 0000/0018 | Loss: 0.0581
# Epoch: 024/050 | Batch 0003/0018 | Loss: 0.0468
# Epoch: 024/050 | Batch 0006/0018 | Loss: 0.0705
# Epoch: 024/050 | Batch 0009/0018 | Loss: 0.0791
# Epoch: 024/050 | Batch 0012/0018 | Loss: 0.0931
# Epoch: 024/050 | Batch 0015/0018 | Loss: 0.0745
# Epoch: 024/050 | Train: 97.55% | Validation: 93.79%
# Time elapsed: 24.99 min
# Epoch: 025/050 | Batch 0000/0018 | Loss: 0.0538
# Epoch: 025/050 | Batch 0003/0018 | Loss: 0.0728
# Epoch: 025/050 | Batch 0006/0018 | Loss: 0.0814
# Epoch: 025/050 | Batch 0009/0018 | Loss: 0.0381
# Epoch: 025/050 | Batch 0012/0018 | Loss: 0.0487
# Epoch: 025/050 | Batch 0015/0018 | Loss: 0.0546
# Epoch: 025/050 | Train: 97.73% | Validation: 92.87%
# Time elapsed: 26.20 min
# Epoch: 026/050 | Batch 0000/0018 | Loss: 0.0630
# Epoch: 026/050 | Batch 0003/0018 | Loss: 0.0386
# Epoch: 026/050 | Batch 0006/0018 | Loss: 0.0712
# Epoch: 026/050 | Batch 0009/0018 | Loss: 0.0825
# Epoch: 026/050 | Batch 0012/0018 | Loss: 0.0223
# Epoch: 026/050 | Batch 0015/0018 | Loss: 0.0981
# Epoch: 026/050 | Train: 97.84% | Validation: 93.53%
# Time elapsed: 27.24 min
# Epoch: 027/050 | Batch 0000/0018 | Loss: 0.0466
# Epoch: 027/050 | Batch 0003/0018 | Loss: 0.0611
# Epoch: 027/050 | Batch 0006/0018 | Loss: 0.0679
# Epoch: 027/050 | Batch 0009/0018 | Loss: 0.0137
# Epoch: 027/050 | Batch 0012/0018 | Loss: 0.0748
# Epoch: 027/050 | Batch 0015/0018 | Loss: 0.0168
# Epoch: 027/050 | Train: 96.12% | Validation: 93.26%
# Time elapsed: 28.27 min
# Epoch: 028/050 | Batch 0000/0018 | Loss: 0.0069
# Epoch: 028/050 | Batch 0003/0018 | Loss: 0.0196
# Epoch: 028/050 | Batch 0006/0018 | Loss: 0.0412
# Epoch: 028/050 | Batch 0009/0018 | Loss: 0.0134
# Epoch: 028/050 | Batch 0012/0018 | Loss: 0.0331
# Epoch: 028/050 | Batch 0015/0018 | Loss: 0.0134
# Epoch: 028/050 | Train: 95.78% | Validation: 92.73%
# Time elapsed: 29.32 min
# Epoch: 029/050 | Batch 0000/0018 | Loss: 0.0075
# Epoch: 029/050 | Batch 0003/0018 | Loss: 0.0323
# Epoch: 029/050 | Batch 0006/0018 | Loss: 0.0619
# Epoch: 029/050 | Batch 0009/0018 | Loss: 0.0082
# Epoch: 029/050 | Batch 0012/0018 | Loss: 0.0275
# Epoch: 029/050 | Batch 0015/0018 | Loss: 0.0318
# Epoch: 029/050 | Train: 99.21% | Validation: 93.92%
# Time elapsed: 30.34 min
# Epoch: 030/050 | Batch 0000/0018 | Loss: 0.0027
# Epoch: 030/050 | Batch 0003/0018 | Loss: 0.0093
# Epoch: 030/050 | Batch 0006/0018 | Loss: 0.0498
# Epoch: 030/050 | Batch 0009/0018 | Loss: 0.0158
# Epoch: 030/050 | Batch 0012/0018 | Loss: 0.0212
# Epoch: 030/050 | Batch 0015/0018 | Loss: 0.0064
# Epoch: 030/050 | Train: 99.62% | Validation: 94.45%
# Time elapsed: 31.37 min
# Epoch: 031/050 | Batch 0000/0018 | Loss: 0.0035
# Epoch: 031/050 | Batch 0003/0018 | Loss: 0.0049
# Epoch: 031/050 | Batch 0006/0018 | Loss: 0.0301
# Epoch: 031/050 | Batch 0009/0018 | Loss: 0.0076
# Epoch: 031/050 | Batch 0012/0018 | Loss: 0.0077
# Epoch: 031/050 | Batch 0015/0018 | Loss: 0.0022
# Epoch: 031/050 | Train: 95.17% | Validation: 90.89%
# Time elapsed: 32.39 min
# Epoch: 032/050 | Batch 0000/0018 | Loss: 0.0064
# Epoch: 032/050 | Batch 0003/0018 | Loss: 0.0345
# Epoch: 032/050 | Batch 0006/0018 | Loss: 0.0317
# Epoch: 032/050 | Batch 0009/0018 | Loss: 0.0316
# Epoch: 032/050 | Batch 0012/0018 | Loss: 0.0111
# Epoch: 032/050 | Batch 0015/0018 | Loss: 0.0022
# Epoch: 032/050 | Train: 96.14% | Validation: 91.28%
# Time elapsed: 33.37 min
# Epoch: 033/050 | Batch 0000/0018 | Loss: 0.0304
# Epoch: 033/050 | Batch 0003/0018 | Loss: 0.0119
# Epoch: 033/050 | Batch 0006/0018 | Loss: 0.0316
# Epoch: 033/050 | Batch 0009/0018 | Loss: 0.0053
# Epoch: 033/050 | Batch 0012/0018 | Loss: 0.0389
# Epoch: 033/050 | Batch 0015/0018 | Loss: 0.0204
# Epoch: 033/050 | Train: 97.93% | Validation: 93.66%
# Time elapsed: 34.40 min
# Epoch: 034/050 | Batch 0000/0018 | Loss: 0.0172
# Epoch: 034/050 | Batch 0003/0018 | Loss: 0.0131
# Epoch: 034/050 | Batch 0006/0018 | Loss: 0.0491
# Epoch: 034/050 | Batch 0009/0018 | Loss: 0.0069
# Epoch: 034/050 | Batch 0012/0018 | Loss: 0.0147
# Epoch: 034/050 | Batch 0015/0018 | Loss: 0.0045
# Epoch: 034/050 | Train: 97.90% | Validation: 93.79%
# Time elapsed: 35.53 min
# Epoch: 035/050 | Batch 0000/0018 | Loss: 0.0085
# Epoch: 035/050 | Batch 0003/0018 | Loss: 0.0030
# Epoch: 035/050 | Batch 0006/0018 | Loss: 0.0234
# Epoch: 035/050 | Batch 0009/0018 | Loss: 0.0264
# Epoch: 035/050 | Batch 0012/0018 | Loss: 0.0039
# Epoch: 035/050 | Batch 0015/0018 | Loss: 0.0123
# Epoch: 035/050 | Train: 99.51% | Validation: 94.06%
# Time elapsed: 36.54 min
# Epoch: 036/050 | Batch 0000/0018 | Loss: 0.0007
# Epoch: 036/050 | Batch 0003/0018 | Loss: 0.0040
# Epoch: 036/050 | Batch 0006/0018 | Loss: 0.0510
# Epoch: 036/050 | Batch 0009/0018 | Loss: 0.0007
# Epoch: 036/050 | Batch 0012/0018 | Loss: 0.0088
# Epoch: 036/050 | Batch 0015/0018 | Loss: 0.0076
# Epoch: 036/050 | Train: 98.61% | Validation: 93.53%
# Time elapsed: 37.64 min
# Epoch: 037/050 | Batch 0000/0018 | Loss: 0.0141
# Epoch: 037/050 | Batch 0003/0018 | Loss: 0.0177
# Epoch: 037/050 | Batch 0006/0018 | Loss: 0.0319
# Epoch: 037/050 | Batch 0009/0018 | Loss: 0.0032
# Epoch: 037/050 | Batch 0012/0018 | Loss: 0.0146
# Epoch: 037/050 | Batch 0015/0018 | Loss: 0.0273
# Epoch: 037/050 | Train: 99.78% | Validation: 94.58%
# Time elapsed: 38.84 min
# Epoch: 038/050 | Batch 0000/0018 | Loss: 0.0046
# Epoch: 038/050 | Batch 0003/0018 | Loss: 0.0491
# Epoch: 038/050 | Batch 0006/0018 | Loss: 0.0242
# Epoch: 038/050 | Batch 0009/0018 | Loss: 0.0233
# Epoch: 038/050 | Batch 0012/0018 | Loss: 0.0140
# Epoch: 038/050 | Batch 0015/0018 | Loss: 0.0073
# Epoch: 038/050 | Train: 99.29% | Validation: 93.53%
# Time elapsed: 40.06 min
# Epoch: 039/050 | Batch 0000/0018 | Loss: 0.0199
# Epoch: 039/050 | Batch 0003/0018 | Loss: 0.0024
# Epoch: 039/050 | Batch 0006/0018 | Loss: 0.0292
# Epoch: 039/050 | Batch 0009/0018 | Loss: 0.0078
# Epoch: 039/050 | Batch 0012/0018 | Loss: 0.0047
# Epoch: 039/050 | Batch 0015/0018 | Loss: 0.0090
# Epoch: 039/050 | Train: 99.56% | Validation: 94.19%
# Time elapsed: 41.31 min
# Epoch: 040/050 | Batch 0000/0018 | Loss: 0.0206
# Epoch: 040/050 | Batch 0003/0018 | Loss: 0.0136
# Epoch: 040/050 | Batch 0006/0018 | Loss: 0.0183
# Epoch: 040/050 | Batch 0009/0018 | Loss: 0.0054
# Epoch: 040/050 | Batch 0012/0018 | Loss: 0.0112
# Epoch: 040/050 | Batch 0015/0018 | Loss: 0.0081
# Epoch: 040/050 | Train: 99.38% | Validation: 93.79%
# Time elapsed: 42.45 min
# Epoch: 041/050 | Batch 0000/0018 | Loss: 0.0303
# Epoch: 041/050 | Batch 0003/0018 | Loss: 0.0158
# Epoch: 041/050 | Batch 0006/0018 | Loss: 0.0369
# Epoch: 041/050 | Batch 0009/0018 | Loss: 0.0078
# Epoch: 041/050 | Batch 0012/0018 | Loss: 0.0202
# Epoch: 041/050 | Batch 0015/0018 | Loss: 0.0024
# Epoch: 041/050 | Train: 98.61% | Validation: 92.87%
# Time elapsed: 43.64 min
# Epoch: 042/050 | Batch 0000/0018 | Loss: 0.0250
# Epoch: 042/050 | Batch 0003/0018 | Loss: 0.0017
# Epoch: 042/050 | Batch 0006/0018 | Loss: 0.0501
# Epoch: 042/050 | Batch 0009/0018 | Loss: 0.0093
# Epoch: 042/050 | Batch 0012/0018 | Loss: 0.0271
# Epoch: 042/050 | Batch 0015/0018 | Loss: 0.0072
# Epoch: 042/050 | Train: 92.67% | Validation: 87.58%
# Time elapsed: 44.79 min
# Epoch: 043/050 | Batch 0000/0018 | Loss: 0.0369
# Epoch: 043/050 | Batch 0003/0018 | Loss: 0.0122
# Epoch: 043/050 | Batch 0006/0018 | Loss: 0.0353
# Epoch: 043/050 | Batch 0009/0018 | Loss: 0.0325
# Epoch: 043/050 | Batch 0012/0018 | Loss: 0.0076
# Epoch: 043/050 | Batch 0015/0018 | Loss: 0.0050
# Epoch: 043/050 | Train: 97.64% | Validation: 92.73%
# Time elapsed: 45.93 min
# Epoch: 044/050 | Batch 0000/0018 | Loss: 0.0120
# Epoch: 044/050 | Batch 0003/0018 | Loss: 0.0203
# Epoch: 044/050 | Batch 0006/0018 | Loss: 0.0324
# Epoch: 044/050 | Batch 0009/0018 | Loss: 0.0322
# Epoch: 044/050 | Batch 0012/0018 | Loss: 0.0057
# Epoch: 044/050 | Batch 0015/0018 | Loss: 0.0033
# Epoch: 044/050 | Train: 98.48% | Validation: 92.34%
# Time elapsed: 47.09 min
# Epoch: 045/050 | Batch 0000/0018 | Loss: 0.0221
# Epoch: 045/050 | Batch 0003/0018 | Loss: 0.0026
# Epoch: 045/050 | Batch 0006/0018 | Loss: 0.0497
# Epoch: 045/050 | Batch 0009/0018 | Loss: 0.0022
# Epoch: 045/050 | Batch 0012/0018 | Loss: 0.0448
# Epoch: 045/050 | Batch 0015/0018 | Loss: 0.0124
# Epoch: 045/050 | Train: 99.43% | Validation: 93.92%
# Time elapsed: 48.18 min
# Epoch: 046/050 | Batch 0000/0018 | Loss: 0.0079
# Epoch: 046/050 | Batch 0003/0018 | Loss: 0.0199
# Epoch: 046/050 | Batch 0006/0018 | Loss: 0.0087
# Epoch: 046/050 | Batch 0009/0018 | Loss: 0.0220
# Epoch: 046/050 | Batch 0012/0018 | Loss: 0.0239
# Epoch: 046/050 | Batch 0015/0018 | Loss: 0.0089
# Epoch: 046/050 | Train: 99.54% | Validation: 94.45%
# Time elapsed: 49.28 min
# Epoch: 047/050 | Batch 0000/0018 | Loss: 0.0014
# Epoch: 047/050 | Batch 0003/0018 | Loss: 0.0184
# Epoch: 047/050 | Batch 0006/0018 | Loss: 0.0098
# Epoch: 047/050 | Batch 0009/0018 | Loss: 0.0431
# Epoch: 047/050 | Batch 0012/0018 | Loss: 0.0061
# Epoch: 047/050 | Batch 0015/0018 | Loss: 0.0288
# Epoch: 047/050 | Train: 95.94% | Validation: 91.94%
# Time elapsed: 50.43 min
# Epoch: 048/050 | Batch 0000/0018 | Loss: 0.0177
# Epoch: 048/050 | Batch 0003/0018 | Loss: 0.0080
# Epoch: 048/050 | Batch 0006/0018 | Loss: 0.0198
# Epoch: 048/050 | Batch 0009/0018 | Loss: 0.0254
# Epoch: 048/050 | Batch 0012/0018 | Loss: 0.0039
# Epoch: 048/050 | Batch 0015/0018 | Loss: 0.0014
# Epoch: 048/050 | Train: 99.23% | Validation: 93.92%
# Time elapsed: 51.56 min
# Epoch: 049/050 | Batch 0000/0018 | Loss: 0.0035
# Epoch: 049/050 | Batch 0003/0018 | Loss: 0.0062
# Epoch: 049/050 | Batch 0006/0018 | Loss: 0.0057
# Epoch: 049/050 | Batch 0009/0018 | Loss: 0.0028
# Epoch: 049/050 | Batch 0012/0018 | Loss: 0.0040
# Epoch: 049/050 | Batch 0015/0018 | Loss: 0.0054
# Epoch: 049/050 | Train: 98.96% | Validation: 94.32%
# Time elapsed: 52.65 min
# Epoch: 050/050 | Batch 0000/0018 | Loss: 0.0027
# Epoch: 050/050 | Batch 0003/0018 | Loss: 0.0056
# Epoch: 050/050 | Batch 0006/0018 | Loss: 0.0408
# Epoch: 050/050 | Batch 0009/0018 | Loss: 0.0058
# Epoch: 050/050 | Batch 0012/0018 | Loss: 0.0086
# Epoch: 050/050 | Batch 0015/0018 | Loss: 0.0193
# Epoch: 050/050 | Train: 99.78% | Validation: 94.32%
# Time elapsed: 53.78 min
# Total Training Time: 53.78 min
# Test accuracy 94.04%

# %%
torch.save(model.state_dict(), 'AlexNet_model.pt')
torch.save(optimizer.state_dict(), 'AlexNet_optimizer.pt')
torch.save(scheduler.state_dict(), 'AlexNet_scheduler.pt')
