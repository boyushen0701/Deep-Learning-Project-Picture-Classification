# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import os
from helper_evaluation import set_all_seeds, set_deterministic
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples

RANDOM_SEED = 1
BATCH_SIZE = 256
NUM_EPOCHS = 30
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
set_all_seeds(RANDOM_SEED)

transform = torchvision.transforms.Compose([
        torchvision.transforms.Resize((64,64)),
        torchvision.transforms.Grayscale(),
        torchvision.transforms.ToTensor(), 
        torchvision.transforms.Normalize((0.5,),(0.5,))
    ])

# Load images 
dataset_dir = './data'
dataset = torchvision.datasets.ImageFolder(root = dataset_dir, transform = transform)

# Determine sizes of the training set and the test set
total_size = len(dataset)
train_size = int(np.floor(total_size * 0.6))
test_size = int(np.floor(total_size * 0.3))
valid_size = total_size - test_size - train_size

# %%
# Split the entire dataset into 60% of training set, 30% of test set, and 10% validation set.
training_dataset, test_dataset, valid_dataset = torch.utils.data.random_split(dataset, [train_size, test_size, valid_size])

# %%
# Loaders
train_loader = torch.utils.data.DataLoader(training_dataset, batch_size = BATCH_SIZE, shuffle = False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle = False)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size = BATCH_SIZE, shuffle = False)

# %%
class AllConvolutional(torch.nn.Module):
    def __init__(self, num_classes, grayscale = False):
        super().__init__()
        self.grayscale = grayscale
        self.num_classes = num_classes
        
        if self.grayscale:
            in_channels = 1
        else:
            in_channels = 3
        
        self.net = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels, 16, kernel_size = 3, stride = 1, padding = 1, bias = False),
            torch.nn.BatchNorm2d(16),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Conv2d(16,16,kernel_size = 3, stride = 2, padding = 1, bias = False),
            torch.nn.BatchNorm2d(16),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Conv2d(16,32,kernel_size = 3, stride = 1, padding = 1, bias = False),
            torch.nn.BatchNorm2d(32),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Conv2d(32,32,kernel_size = 3, stride = 2, padding = 1, bias = False),
            torch.nn.BatchNorm2d(32),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Conv2d(32,64,kernel_size = 3, stride = 1, padding = 1, bias = False),
            torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Conv2d(64,64,kernel_size = 3, stride = 2, padding = 1, bias = False),
            torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(inplace = True),
            
            torch.nn.Conv2d(64,num_classes, kernel_size = 3, stride = 1, padding = 1, bias = False),
            torch.nn.BatchNorm2d(num_classes),
            torch.nn.ReLU(inplace = True),
            torch.nn.AdaptiveAvgPool2d(1),
            torch.nn.Flatten()
        )

    def forward(self, x):
        x = self.net(x)
        return x

# %%
model = AllConvolutional(grayscale = True, num_classes = 2)
model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr = 0.1, momentum = 0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.1,
                                                       mode='max',
                                                       verbose=True)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    test_loader=test_loader,
    valid_loader = valid_loader,
    optimizer=optimizer,
    device=DEVICE,
    logging_interval=3)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=100)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([80, 100])
plt.show()
# Out:
# Epoch: 001/030 | Batch 0000/0018 | Loss: 0.6734
# Epoch: 001/030 | Batch 0003/0018 | Loss: 0.5573
# Epoch: 001/030 | Batch 0006/0018 | Loss: 0.5912
# Epoch: 001/030 | Batch 0009/0018 | Loss: 0.5905
# Epoch: 001/030 | Batch 0012/0018 | Loss: 0.5809
# Epoch: 001/030 | Batch 0015/0018 | Loss: 0.5434
# Epoch: 001/030 | Train: 70.12% | Validation: 70.94%
# Time elapsed: 1.02 min
# Epoch: 002/030 | Batch 0000/0018 | Loss: 0.5062
# Epoch: 002/030 | Batch 0003/0018 | Loss: 0.4698
# Epoch: 002/030 | Batch 0006/0018 | Loss: 0.5114
# Epoch: 002/030 | Batch 0009/0018 | Loss: 0.5139
# Epoch: 002/030 | Batch 0012/0018 | Loss: 0.4961
# Epoch: 002/030 | Batch 0015/0018 | Loss: 0.4347
# Epoch: 002/030 | Train: 75.88% | Validation: 73.18%
# Time elapsed: 2.02 min
# Epoch: 003/030 | Batch 0000/0018 | Loss: 0.4272
# Epoch: 003/030 | Batch 0003/0018 | Loss: 0.3839
# Epoch: 003/030 | Batch 0006/0018 | Loss: 0.4380
# Epoch: 003/030 | Batch 0009/0018 | Loss: 0.4174
# Epoch: 003/030 | Batch 0012/0018 | Loss: 0.4218
# Epoch: 003/030 | Batch 0015/0018 | Loss: 0.3852
# Epoch: 003/030 | Train: 64.53% | Validation: 64.46%
# Time elapsed: 2.88 min
# Epoch: 004/030 | Batch 0000/0018 | Loss: 0.3865
# Epoch: 004/030 | Batch 0003/0018 | Loss: 0.3593
# Epoch: 004/030 | Batch 0006/0018 | Loss: 0.3914
# Epoch: 004/030 | Batch 0009/0018 | Loss: 0.3610
# Epoch: 004/030 | Batch 0012/0018 | Loss: 0.3692
# Epoch: 004/030 | Batch 0015/0018 | Loss: 0.3184
# Epoch: 004/030 | Train: 85.92% | Validation: 85.73%
# Time elapsed: 3.74 min
# Epoch: 005/030 | Batch 0000/0018 | Loss: 0.2906
# Epoch: 005/030 | Batch 0003/0018 | Loss: 0.2734
# Epoch: 005/030 | Batch 0006/0018 | Loss: 0.2985
# Epoch: 005/030 | Batch 0009/0018 | Loss: 0.3003
# Epoch: 005/030 | Batch 0012/0018 | Loss: 0.3014
# Epoch: 005/030 | Batch 0015/0018 | Loss: 0.2610
# Epoch: 005/030 | Train: 85.24% | Validation: 83.88%
# Time elapsed: 4.62 min
# Epoch: 006/030 | Batch 0000/0018 | Loss: 0.2233
# Epoch: 006/030 | Batch 0003/0018 | Loss: 0.2237
# Epoch: 006/030 | Batch 0006/0018 | Loss: 0.2654
# Epoch: 006/030 | Batch 0009/0018 | Loss: 0.2319
# Epoch: 006/030 | Batch 0012/0018 | Loss: 0.2676
# Epoch: 006/030 | Batch 0015/0018 | Loss: 0.2526
# Epoch: 006/030 | Train: 73.43% | Validation: 73.84%
# Time elapsed: 5.49 min
# Epoch: 007/030 | Batch 0000/0018 | Loss: 0.1922
# Epoch: 007/030 | Batch 0003/0018 | Loss: 0.2257
# Epoch: 007/030 | Batch 0006/0018 | Loss: 0.2127
# Epoch: 007/030 | Batch 0009/0018 | Loss: 0.2163
# Epoch: 007/030 | Batch 0012/0018 | Loss: 0.2151
# Epoch: 007/030 | Batch 0015/0018 | Loss: 0.1741
# Epoch: 007/030 | Train: 90.51% | Validation: 88.64%
# Time elapsed: 6.38 min
# Epoch: 008/030 | Batch 0000/0018 | Loss: 0.1523
# Epoch: 008/030 | Batch 0003/0018 | Loss: 0.1969
# Epoch: 008/030 | Batch 0006/0018 | Loss: 0.2020
# Epoch: 008/030 | Batch 0009/0018 | Loss: 0.2331
# Epoch: 008/030 | Batch 0012/0018 | Loss: 0.1972
# Epoch: 008/030 | Batch 0015/0018 | Loss: 0.1349
# Epoch: 008/030 | Train: 92.52% | Validation: 89.83%
# Time elapsed: 7.26 min
# Epoch: 009/030 | Batch 0000/0018 | Loss: 0.1373
# Epoch: 009/030 | Batch 0003/0018 | Loss: 0.1792
# Epoch: 009/030 | Batch 0006/0018 | Loss: 0.1763
# Epoch: 009/030 | Batch 0009/0018 | Loss: 0.2153
# Epoch: 009/030 | Batch 0012/0018 | Loss: 0.2148
# Epoch: 009/030 | Batch 0015/0018 | Loss: 0.1853
# Epoch: 009/030 | Train: 80.87% | Validation: 79.92%
# Time elapsed: 8.17 min
# Epoch: 010/030 | Batch 0000/0018 | Loss: 0.1421
# Epoch: 010/030 | Batch 0003/0018 | Loss: 0.1826
# Epoch: 010/030 | Batch 0006/0018 | Loss: 0.1674
# Epoch: 010/030 | Batch 0009/0018 | Loss: 0.2132
# Epoch: 010/030 | Batch 0012/0018 | Loss: 0.1576
# Epoch: 010/030 | Batch 0015/0018 | Loss: 0.1386
# Epoch: 010/030 | Train: 79.76% | Validation: 77.28%
# Time elapsed: 9.03 min
# Epoch: 011/030 | Batch 0000/0018 | Loss: 0.1286
# Epoch: 011/030 | Batch 0003/0018 | Loss: 0.1242
# Epoch: 011/030 | Batch 0006/0018 | Loss: 0.1479
# Epoch: 011/030 | Batch 0009/0018 | Loss: 0.1392
# Epoch: 011/030 | Batch 0012/0018 | Loss: 0.1255
# Epoch: 011/030 | Batch 0015/0018 | Loss: 0.0956
# Epoch: 011/030 | Train: 95.54% | Validation: 91.28%
# Time elapsed: 9.89 min
# Epoch: 012/030 | Batch 0000/0018 | Loss: 0.0898
# Epoch: 012/030 | Batch 0003/0018 | Loss: 0.0882
# Epoch: 012/030 | Batch 0006/0018 | Loss: 0.1040
# Epoch: 012/030 | Batch 0009/0018 | Loss: 0.1075
# Epoch: 012/030 | Batch 0012/0018 | Loss: 0.1050
# Epoch: 012/030 | Batch 0015/0018 | Loss: 0.0907
# Epoch: 012/030 | Train: 90.20% | Validation: 85.87%
# Time elapsed: 10.76 min
# Epoch: 013/030 | Batch 0000/0018 | Loss: 0.0776
# Epoch: 013/030 | Batch 0003/0018 | Loss: 0.0874
# Epoch: 013/030 | Batch 0006/0018 | Loss: 0.0716
# Epoch: 013/030 | Batch 0009/0018 | Loss: 0.0987
# Epoch: 013/030 | Batch 0012/0018 | Loss: 0.0908
# Epoch: 013/030 | Batch 0015/0018 | Loss: 0.1039
# Epoch: 013/030 | Train: 93.33% | Validation: 89.04%
# Time elapsed: 11.68 min
# Epoch: 014/030 | Batch 0000/0018 | Loss: 0.0786
# Epoch: 014/030 | Batch 0003/0018 | Loss: 0.0740
# Epoch: 014/030 | Batch 0006/0018 | Loss: 0.0830
# Epoch: 014/030 | Batch 0009/0018 | Loss: 0.0843
# Epoch: 014/030 | Batch 0012/0018 | Loss: 0.0737
# Epoch: 014/030 | Batch 0015/0018 | Loss: 0.0551
# Epoch: 014/030 | Train: 94.22% | Validation: 88.77%
# Time elapsed: 12.54 min
# Epoch: 015/030 | Batch 0000/0018 | Loss: 0.0593
# Epoch: 015/030 | Batch 0003/0018 | Loss: 0.0647
# Epoch: 015/030 | Batch 0006/0018 | Loss: 0.0748
# Epoch: 015/030 | Batch 0009/0018 | Loss: 0.0880
# Epoch: 015/030 | Batch 0012/0018 | Loss: 0.0583
# Epoch: 015/030 | Batch 0015/0018 | Loss: 0.0544
# Epoch: 015/030 | Train: 94.55% | Validation: 89.43%
# Time elapsed: 13.40 min
# Epoch: 016/030 | Batch 0000/0018 | Loss: 0.0555
# Epoch: 016/030 | Batch 0003/0018 | Loss: 0.0433
# Epoch: 016/030 | Batch 0006/0018 | Loss: 0.0628
# Epoch: 016/030 | Batch 0009/0018 | Loss: 0.0687
# Epoch: 016/030 | Batch 0012/0018 | Loss: 0.0528
# Epoch: 016/030 | Batch 0015/0018 | Loss: 0.0603
# Epoch: 016/030 | Train: 95.70% | Validation: 88.90%
# Time elapsed: 14.26 min
# Epoch: 017/030 | Batch 0000/0018 | Loss: 0.0548
# Epoch: 017/030 | Batch 0003/0018 | Loss: 0.0383
# Epoch: 017/030 | Batch 0006/0018 | Loss: 0.0599
# Epoch: 017/030 | Batch 0009/0018 | Loss: 0.0476
# Epoch: 017/030 | Batch 0012/0018 | Loss: 0.0685
# Epoch: 017/030 | Batch 0015/0018 | Loss: 0.0353
# Epoch: 017/030 | Train: 98.17% | Validation: 91.55%
# Time elapsed: 15.11 min
# Epoch: 018/030 | Batch 0000/0018 | Loss: 0.0366
# Epoch: 018/030 | Batch 0003/0018 | Loss: 0.0476
# Epoch: 018/030 | Batch 0006/0018 | Loss: 0.0335
# Epoch: 018/030 | Batch 0009/0018 | Loss: 0.0503
# Epoch: 018/030 | Batch 0012/0018 | Loss: 0.0417
# Epoch: 018/030 | Batch 0015/0018 | Loss: 0.0332
# Epoch: 018/030 | Train: 99.58% | Validation: 93.39%
# Time elapsed: 15.97 min
# Epoch: 019/030 | Batch 0000/0018 | Loss: 0.0311
# Epoch: 019/030 | Batch 0003/0018 | Loss: 0.0328
# Epoch: 019/030 | Batch 0006/0018 | Loss: 0.0352
# Epoch: 019/030 | Batch 0009/0018 | Loss: 0.0389
# Epoch: 019/030 | Batch 0012/0018 | Loss: 0.0317
# Epoch: 019/030 | Batch 0015/0018 | Loss: 0.0264
# Epoch: 019/030 | Train: 99.74% | Validation: 94.19%
# Time elapsed: 16.83 min
# Epoch: 020/030 | Batch 0000/0018 | Loss: 0.0249
# Epoch: 020/030 | Batch 0003/0018 | Loss: 0.0287
# Epoch: 020/030 | Batch 0006/0018 | Loss: 0.0305
# Epoch: 020/030 | Batch 0009/0018 | Loss: 0.0345
# Epoch: 020/030 | Batch 0012/0018 | Loss: 0.0238
# Epoch: 020/030 | Batch 0015/0018 | Loss: 0.0218
# Epoch: 020/030 | Train: 99.10% | Validation: 91.15%
# Time elapsed: 17.70 min
# Epoch: 021/030 | Batch 0000/0018 | Loss: 0.0176
# Epoch: 021/030 | Batch 0003/0018 | Loss: 0.0308
# Epoch: 021/030 | Batch 0006/0018 | Loss: 0.0236
# Epoch: 021/030 | Batch 0009/0018 | Loss: 0.0215
# Epoch: 021/030 | Batch 0012/0018 | Loss: 0.0187
# Epoch: 021/030 | Batch 0015/0018 | Loss: 0.0187
# Epoch: 021/030 | Train: 96.98% | Validation: 89.17%
# Time elapsed: 18.59 min
# Epoch: 022/030 | Batch 0000/0018 | Loss: 0.0184
# Epoch: 022/030 | Batch 0003/0018 | Loss: 0.0152
# Epoch: 022/030 | Batch 0006/0018 | Loss: 0.0147
# Epoch: 022/030 | Batch 0009/0018 | Loss: 0.0244
# Epoch: 022/030 | Batch 0012/0018 | Loss: 0.0167
# Epoch: 022/030 | Batch 0015/0018 | Loss: 0.0165
# Epoch: 022/030 | Train: 96.87% | Validation: 86.92%
# Time elapsed: 19.46 min
# Epoch: 023/030 | Batch 0000/0018 | Loss: 0.0154
# Epoch: 023/030 | Batch 0003/0018 | Loss: 0.0149
# Epoch: 023/030 | Batch 0006/0018 | Loss: 0.0148
# Epoch: 023/030 | Batch 0009/0018 | Loss: 0.0182
# Epoch: 023/030 | Batch 0012/0018 | Loss: 0.0116
# Epoch: 023/030 | Batch 0015/0018 | Loss: 0.0150
# Epoch: 023/030 | Train: 96.25% | Validation: 86.53%
# Time elapsed: 20.32 min
# Epoch: 024/030 | Batch 0000/0018 | Loss: 0.0127
# Epoch: 024/030 | Batch 0003/0018 | Loss: 0.0131
# Epoch: 024/030 | Batch 0006/0018 | Loss: 0.0113
# Epoch: 024/030 | Batch 0009/0018 | Loss: 0.0121
# Epoch: 024/030 | Batch 0012/0018 | Loss: 0.0106
# Epoch: 024/030 | Batch 0015/0018 | Loss: 0.0120
# Epoch: 024/030 | Train: 99.14% | Validation: 88.51%
# Time elapsed: 21.18 min
# Epoch: 025/030 | Batch 0000/0018 | Loss: 0.0102
# Epoch: 025/030 | Batch 0003/0018 | Loss: 0.0107
# Epoch: 025/030 | Batch 0006/0018 | Loss: 0.0100
# Epoch: 025/030 | Batch 0009/0018 | Loss: 0.0137
# Epoch: 025/030 | Batch 0012/0018 | Loss: 0.0111
# Epoch: 025/030 | Batch 0015/0018 | Loss: 0.0127
# Epoch: 025/030 | Train: 100.00% | Validation: 93.53%
# Time elapsed: 22.04 min
# Epoch: 026/030 | Batch 0000/0018 | Loss: 0.0089
# Epoch: 026/030 | Batch 0003/0018 | Loss: 0.0096
# Epoch: 026/030 | Batch 0006/0018 | Loss: 0.0103
# Epoch: 026/030 | Batch 0009/0018 | Loss: 0.0089
# Epoch: 026/030 | Batch 0012/0018 | Loss: 0.0088
# Epoch: 026/030 | Batch 0015/0018 | Loss: 0.0105
# Epoch: 026/030 | Train: 100.00% | Validation: 94.19%
# Time elapsed: 22.89 min
# Epoch: 027/030 | Batch 0000/0018 | Loss: 0.0073
# Epoch: 027/030 | Batch 0003/0018 | Loss: 0.0073
# Epoch: 027/030 | Batch 0006/0018 | Loss: 0.0072
# Epoch: 027/030 | Batch 0009/0018 | Loss: 0.0074
# Epoch: 027/030 | Batch 0012/0018 | Loss: 0.0067
# Epoch: 027/030 | Batch 0015/0018 | Loss: 0.0074
# Epoch: 027/030 | Train: 100.00% | Validation: 94.19%
# Time elapsed: 23.75 min
# Epoch: 028/030 | Batch 0000/0018 | Loss: 0.0058
# Epoch: 028/030 | Batch 0003/0018 | Loss: 0.0055
# Epoch: 028/030 | Batch 0006/0018 | Loss: 0.0057
# Epoch: 028/030 | Batch 0009/0018 | Loss: 0.0058
# Epoch: 028/030 | Batch 0012/0018 | Loss: 0.0055
# Epoch: 028/030 | Batch 0015/0018 | Loss: 0.0061
# Epoch: 028/030 | Train: 100.00% | Validation: 93.79%
# Time elapsed: 24.61 min
# Epoch: 029/030 | Batch 0000/0018 | Loss: 0.0049
# Epoch: 029/030 | Batch 0003/0018 | Loss: 0.0050
# Epoch: 029/030 | Batch 0006/0018 | Loss: 0.0050
# Epoch: 029/030 | Batch 0009/0018 | Loss: 0.0051
# Epoch: 029/030 | Batch 0012/0018 | Loss: 0.0050
# Epoch: 029/030 | Batch 0015/0018 | Loss: 0.0056
# Epoch: 029/030 | Train: 100.00% | Validation: 94.72%
# Time elapsed: 25.47 min
# Epoch: 030/030 | Batch 0000/0018 | Loss: 0.0045
# Epoch: 030/030 | Batch 0003/0018 | Loss: 0.0045
# Epoch: 030/030 | Batch 0006/0018 | Loss: 0.0047
# Epoch: 030/030 | Batch 0009/0018 | Loss: 0.0048
# Epoch: 030/030 | Batch 0012/0018 | Loss: 0.0047
# Epoch: 030/030 | Batch 0015/0018 | Loss: 0.0052
# Epoch: 030/030 | Train: 100.00% | Validation: 94.45%
# Time elapsed: 26.37 min
# Total Training Time: 26.37 min
# Test accuracy 92.80%

# %%
plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([60, 100])
plt.show()
